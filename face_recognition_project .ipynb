# %%
import os
import warnings
warnings.simplefilter('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
karthi = os.listdir("D:/python/karthic")
mani = os.listdir("D:/python/mani")
jeeva = os.listdir("D:/python/Jeeva")

# %%
limit = 20
karthi_image= [None]*limit
j=0
for i in karthi:
    if (j<limit):
        karthi_image[j] = imread("D:/python/karthic/"+i)
        j += 1
    else:
        break

# %%
limit = 20
mani_image= [None]*limit
j=0
for i in mani:
    if (j<limit):
        mani_image[j] = imread("D:/python/mani/"+i)
        j += 1
    else:
        break

# %%
limit = 20
jeeva_image= [None]*limit
j=0
for i in jeeva:
    if (j<limit):
        jeeva_image[j] = imread("D:/python/Jeeva/"+i)
        j += 1
    else:
        break

# %%
imshow(mani_image[4])

# %%
imshow(karthi_image[16])

# %%
imshow(jeeva_image[18])

# %%
karthi_gray = [None]*limit
j = 0
for i in karthi:
    if (j<limit):
        karthi_gray[j] = rgb2gray(karthi_image[j])
        j+=1
    else:
        break

# %%
jeeva_gray = [None]*limit
j = 0
for i in jeeva:
    if (j<limit):
        jeeva_gray[j] = rgb2gray(jeeva_image[j])
        j+=1
    else:
        break

# %%
mani_gray = [None]*limit
j = 0
for i in mani:
    if (j<limit):
        mani_gray[j] = rgb2gray(mani_image[j])
        j+=1
    else:
        break

# %%
imshow(karthi_gray[16])

# %%
imshow(mani_gray[4])

# %%
for j in range (20):
    gp = karthi_gray[j]
    karthi_gray[j] = resize(gp,(512,512))

# %%
for j in range (19):
    gp = jeeva_gray[j]
    jeeva_gray[j] = resize(gp,(512,512))

# %%
for j in range (20):
    gp = mani_gray[j]
    mani_gray[j] = resize(gp,(512,512))

# %%
imshow(jeeva_gray[18])

# %%
karthi_gray[18].shape
# Out:
# (512, 512)

# %%
len_of_image_karthi = len(karthi_gray)

# %%
len_of_image_karthi
# Out:
# 20

# %%
im_size_karthi = karthi_gray[2].shape

# %%
im_size_karthi
# Out:
# (512, 512)

# %%
flat_size_karthi = im_size_karthi[0]*im_size_karthi[1]

# %%
for i in range(len_of_image_karthi):
    karthi_gray[i] = np.ndarray.flatten(karthi_gray[2]).reshape(flat_size_karthi,1)

# %%
karthi_gray=np.dstack(karthi_gray)

# %%
karthi_gray.shape
# Out:
# (262144, 1, 20)

# %%
karthi_gray = np.rollaxis(karthi_gray,axis = 2,start = 0)

# %%
karthi_gray.shape
# Out:
# (20, 262144, 1)

# %%
karthi_gray = karthi_gray.reshape(len_of_image_karthi,flat_size_karthi)

# %%
karthi_gray.shape
# Out:
# (20, 262144)

# %%
karthi_data = pd.DataFrame(karthi_gray)

# %%
karthi_data
# Out:
#       0         1         2         3         4         5        6       \
# 0   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 1   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 2   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 3   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 4   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 5   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 6   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 7   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 8   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 9   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 10  0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 11  0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# ...

# %%
karthi_data["label"]= "karthic"

# %%
karthi_data
# Out:
#            0         1         2         3         4         5        6  \
# 0   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 1   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 2   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 3   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 4   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 5   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 6   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 7   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 8   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 9   0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 10  0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# 11  0.330127  0.249114  0.229642  0.238508  0.236969  0.218852  0.22576
# ...

# %%
len_of_image_mani = len(mani_gray)

# %%
len_of_image_jeeva = len(jeeva_gray)

# %%
im_size_mani = mani_gray[2].shape

# %%
im_size_jeeva = jeeva_gray[2].shape

# %%
flat_size_mani = im_size_mani[0]*im_size_mani[1]

# %%
flat_size_jeeva = im_size_jeeva[0]*im_size_jeeva[1]

# %%
for i in range(len_of_image_mani):
    mani_gray[i] = np.ndarray.flatten(mani_gray[2]).reshape(flat_size_mani,1)

# %%
for i in range(len_of_image_jeeva):
    jeeva_gray[i] = np.ndarray.flatten(jeeva_gray[2]).reshape(flat_size_jeeva,1)

# %%
mani_gray=np.dstack(mani_gray)

# %%
jeeva_gray=np.dstack(jeeva_gray)

# %%
mani_gray.shape
# Out:
# (262144, 1, 20)

# %%
jeeva_gray.shape
# Out:
# (262144, 1, 20)

# %%
mani_gray = np.rollaxis(mani_gray,axis = 2,start = 0)
jeeva_gray = np.rollaxis(jeeva_gray,axis = 2,start = 0)

# %%
jeeva_gray.shape
# Out:
# (20, 262144, 1)

# %%
mani_gray = mani_gray.reshape(len_of_image_mani,flat_size_mani)

# %%
jeeva_gray = jeeva_gray.reshape(len_of_image_jeeva,flat_size_jeeva)

# %%
mani_data = pd.DataFrame(mani_gray)
jeeva_data = pd.DataFrame(jeeva_gray)

# %%
mani_data["label"]= "mani"
jeeva_data["label"]= "jeeva"

# %%
mani_data
# Out:
#            0        1         2         3         4       5         6  \
# 0   0.511864  0.51468  0.520506  0.525563  0.531829  0.5325  0.515431
# 1   0.511864  0.51468  0.520506  0.525563  0.531829  0.5325  0.515431
# 2   0.511864  0.51468  0.520506  0.525563  0.531829  0.5325  0.515431
# 3   0.511864  0.51468  0.520506  0.525563  0.531829  0.5325  0.515431
# 4   0.511864  0.51468  0.520506  0.525563  0.531829  0.5325  0.515431
# 5   0.511864  0.51468  0.520506  0.525563  0.531829  0.5325  0.515431
# 6   0.511864  0.51468  0.520506  0.525563  0.531829  0.5325  0.515431
# 7   0.511864  0.51468  0.520506  0.525563  0.531829  0.5325  0.515431
# 8   0.511864  0.51468  0.520506  0.525563  0.531829  0.5325  0.515431
# 9   0.511864  0.51468  0.520506  0.525563  0.531829  0.5325  0.515431
# 10  0.511864  0.51468  0.520506  0.525563  0.531829  0.5325  0.515431
# 11  0.511864  0.51468  0.520506  0.525563  0.531829  0.5325  0.515431
# ...

# %%
concade_1 = pd.concat([karthi_data,mani_data])

# %%
concade = pd.concat([concade_1,jeeva_data])

# %%
from sklearn.utils import shuffle

# %%
face_index = shuffle(concade).reset_index()

# %%
face_index
# Out:
#     index         0         1         2         3         4         5  \
# 0      11  0.540369  0.540369  0.540369  0.540369  0.540369  0.540369
# 1      16  0.540369  0.540369  0.540369  0.540369  0.540369  0.540369
# 2       5  0.511864  0.514680  0.520506  0.525563  0.531829  0.532500
# 3      13  0.511864  0.514680  0.520506  0.525563  0.531829  0.532500
# 4       6  0.540369  0.540369  0.540369  0.540369  0.540369  0.540369
# 5      12  0.511864  0.514680  0.520506  0.525563  0.531829  0.532500
# 6      19  0.511864  0.514680  0.520506  0.525563  0.531829  0.532500
# 7      15  0.330127  0.249114  0.229642  0.238508  0.236969  0.218852
# 8       9  0.511864  0.514680  0.520506  0.525563  0.531829  0.532500
# 9       7  0.511864  0.514680  0.520506  0.525563  0.531829  0.532500
# 10     15  0.540369  0.540369  0.540369  0.540369  0.540369  0.540369
# 11      3  0.330127  0.249114  0.229642  0.238508  0.236969  0.218852
# ...

# %%
face = face_index.drop(['index'],axis = 1)

# %%
x = face.values[:,: -1]

# %%
y = face.values[:,-1]

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
from sklearn.metrics import confusion_matrix
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)
clf = svm.SVC()
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred = clf.predict(x_test)

# %%
y_pred
# Out:
# array(['karthic', 'jeeva', 'karthic', 'jeeva', 'karthic', 'mani', 'mani',
#        'jeeva', 'karthic', 'karthic', 'jeeva', 'jeeva'], dtype=object)

# %%
for i in (np.random.randint(5,10,19)):
    predicted_image = (np.reshape(x_test[i],([512,512])).astype(np.float64))
    plt.title("predicted label : {}".format(y_pred[i]))
    plt.imshow(predicted_image,interpolation = "nearest" , cmap = "gray")
    plt.show

# %%
accuracy = metrics.accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 1.0

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[5, 0, 0],
#        [0, 5, 0],
#        [0, 0, 2]], dtype=int64)
